# %%
import json
import csv
import requests
url='https://webapi.sporttery.cn/gateway/lottery/getHistoryPageListV1.qry?gameNo=85&'+\
  'provinceId=0&pageSize=30&isVerify=1&pageNo=1'
headers={
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    "accept-language": "en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7",
    "cache-control": "no-cache",
    "pragma": "no-cache",
    "sec-ch-ua": "\" Not;A Brand\";v=\"99\", \"Google Chrome\";v=\"97\", \"Chromium\";v=\"97\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"macOS\"",
    "sec-fetch-dest": "document",
    "sec-fetch-mode": "navigate",
    "sec-fetch-site": "none",
    "sec-fetch-user": "?1",
    "upgrade-insecure-requests": "1"
  }
a=requests.get(url,headers=headers)
print(a.text)
def write_csv(list, csv_writer):
    # item=content['value']['list'][0]
    for item in list:
      prizeList=item['prizeLevelList']
      csv_writer.writerow([item['lotteryDrawNum'],
                          item['lotteryDrawTime'],
                          item['lotteryDrawResult'],
                          prizeList[0]['stakeCount'],
                          prizeList[1]['stakeCount'],
                          prizeList[2]['stakeCount'],
                          prizeList[3]['stakeCount'],
                          prizeList[4]['stakeCount'],
      ])
def json_2_csv(jsonPath, csvPath):
  with open(jsonPath) as f_json:
    with open(csvPath,'w') as f_csv:
      content=json.load(f_json)
      csv_writer=csv.writer(f_csv)
      csv_writer.writerow(['num','time','result','l1','l1x','l2','l2x','l3'])
      write_csv(content['value']['list'],csv_writer)


# jsonPath_1='/content/drive/MyDrive/PythonLearn/lottery/1.json'
# csvPath_1='/content/drive/MyDrive/PythonLearn/lottery/1.csv'
# json_2_csv(jsonPath_1,csvPath_1)

jsonPath_2='/content/drive/MyDrive/PythonLearn/lottery/2.json'
csvPath_2='/content/drive/MyDrive/PythonLearn/lottery/2.csv'
#json_2_csv(jsonPath_2,csvPath_2)

jsonPath_3='/content/drive/MyDrive/PythonLearn/lottery/3.json'
csvPath_3='/content/drive/MyDrive/PythonLearn/lottery/3.csv'
#json_2_csv(jsonPath_3,csvPath_3)
# Out:
# {"dataFrom":"","emptyFlag":false,"errorCode":"0","errorMessage":"处理成功","success":true,"value":{"list":[{"drawFlowFund":"38727154.7","drawFlowFundRj":"","estimateDrawTime":"","isGetKjpdf":1,"isGetXlpdf":2,"lotteryDrawNum":"22016","lotteryDrawResult":"01 07 17 26 32 01 09","lotteryDrawStatus":20,"lotteryDrawTime":"2022-02-16","lotteryEquipmentCount":2,"lotteryGameName":"超级大乐透","lotteryGameNum":"85","lotteryGamePronum":0,"lotteryPaidBeginTime":"2022-02-16 22:00:01","lotteryPaidEndTime":"2022-04-18 23:59:59","lotteryPromotionFlag":0,"lotterySaleBeginTime":"2022-02-14 20:10:00","lotterySaleEndTimeUnix":0,"lotterySaleEndtime":"2022-02-16 20:00:00","lotterySuspendedFlag":0,"lotteryUnsortDrawresult":"01+26+07+32+17 09+01","matchList":[],"pdfType":1,"poolBalanceAfterdraw":"1,140,211,944.72","poolBalanceAfterdrawRj":"","prizeLevelList":[{"awardType":0,"group":"101","lotteryCondition":"","prizeLevel":"一等奖","sort":101,"stakeAmount":"10,000,000","stakeCount":"2","totalPrizeamount":"20,000,000"},{"awardType":0,"group":"201","lotteryCondition":"","prizeLevel":"一等奖(追加)","sort":201,"stakeAmount":"8,000,000","stakeCount":"1","totalPrizeamount":"8,000,000"},{"awardType":0,"group":"301","lotteryCondition":"","prizeLevel":"二等奖","sort":301,"stakeAmount":"195,233","stakeCount":"74","totalPrizeamount":"14,447,242"},{"awardType":0,"group":"401","lotteryCondition":"","prizeLevel":"二等奖(追加)","sort":401,"stakeAmount":"156,186","stakeCount":"28","totalPrizeamount":"4,373,208"},{"awardType":0,"group":"501","lotteryCondition":"","prizeLevel":"三等奖","sort":501,"stakeAmount":"10,000","stakeCount":"335","totalPrizeamount":"3,350,000"},{"awardType":0,"group":"601","lotteryCondition":"","prizeLevel":"四等奖","sort":601,"stakeAmount":"3,000","stakeCount":"394","totalPrizeamount":"1,182,000"},{"awardType":0,"group":"701","lotteryCondition":"","prizeLevel":"五等奖","sort":701,"stakeAmount":"300","stakeCount":"13,663","totalPrizeamount":"4,098,900"},{"awardType":0,"group":"801","lotteryCondition":"","prizeLevel":"六等奖","sort":801,"stakeAmount":"200","stakeCount":"15,670","totalPrizeamount":"3,134,000"},{"awardType":0,"group":"901","lotteryCondition":"","prizeLevel":"七等奖","sort":901,"stakeAmount":"100","stakeCount":"29,562","totalPrizeamount":"2,956,200"},{"awardType":0,"group":"1001","lotteryCondition":"","prizeLevel":"八等奖","sort":1001,"stakeAmount":"15","stakeCount":"573,446","totalPrizeamount":"8,601,690"},{"awardType":0,"group":"1101","lotteryCondition":"","prizeLevel":"九等奖","sort":1101,"stakeAmount":"5","stakeCount":"6,177,125","totalPrizeamount":"30,885,625"}],"prizeLevelListRj":[],"ruleType":0,"termList":[],"totalSaleAmount":"285,216,427","totalSaleAmountRj":"","verify":1,"vtoolsConfig":{}},{"drawFlowFund":"0","drawFlowFundRj":"","estimateDrawTime":"","isGetKjpdf":1,"isGetXlpdf":2,"lotteryDrawNum":"22015","lotteryDrawResult":"01 02 08 12 30 05 12","lotteryDrawStatus":20,"lotteryDrawTime":"2022-02-14","lotteryEquipmentCount":3,"lotteryGameName":"超级大乐透","lotteryGameNum":"85","lotteryGamePronum":0,"lotteryPaidBeginTime":"2022-02-14 22:00:01","lotteryPaidEndTime":"2022-04-15 23:59:59","lotteryPromotionFlag":0,"lotterySaleBeginTime":"2022-02-12 20:10:00","lotterySaleEndTimeUnix":0,"lotterySaleEndtime":"2022-02-14 20:00:00","lotterySuspendedFlag":0,"lotteryUnsortDrawresult":"08+12+01+02+30 05+12","matchList":[],"pdfType":1,"poolBalanceAfterdraw":"1,101,484,790.02","poolBalanceAfterdrawRj":"","prizeLevelList":[{"awardType":0,"group":"101","lotteryCondition":"","prizeLevel":"一等奖","sort":101,"stakeAmount":"6,507,822","stakeCount":"14","totalPrizeamount":"91,109,508"},{"awardType":0,"group":"201","lotteryCondition":"","prizeLevel":"一等奖(追加)","sort":201,"stakeAmount":"5,206,257","stakeCount":"11","totalPrizeamount":"57,268,827"},{"awardType":0,"group":"301","lotteryCondition":"","prizeLevel":"二等奖","sort":301,"stakeAmount":"112,380","stakeCount":"105","totalPrizeamount":"11,799,900"},{"awardType":0,"group":"401","lotteryCondition":"","prizeLevel":"二等奖(追加)","sort":401,"stakeAmount": ...
